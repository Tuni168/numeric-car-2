# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
# %matplotlib inline

# %%
data = pd.read_csv("embo21.csv")

# %%
data.head()
data.describe(include='all')
# Out:
#         Identifier     City    Postal Code     Model Year    Make    Model  \
# count       135038   135030  135030.000000  135038.000000  135038   134789
# unique        9059      651            NaN            NaN      36      125
# top     5YJYGDEE9M  Seattle            NaN            NaN   TESLA  MODEL 3
# freq           473    23489            NaN            NaN   61808    25837
# mean           NaN      NaN   98171.001577    2019.662880     NaN      NaN
# std            NaN      NaN    2450.367211       3.001676     NaN      NaN
# min            NaN      NaN    1730.000000    1997.000000     NaN      NaN
# 25%            NaN      NaN   98052.000000    2018.000000     NaN      NaN
# 50%            NaN      NaN   98121.000000    2021.000000     NaN      NaN
# 75%            NaN      NaN   98370.000000    2022.000000     NaN      NaN
# max            NaN      NaN   99701.000000    2024.000000     NaN      NaN
#
#                  Electric Vehicle Type  \
# ...

# %%
data.describe()
# Out:
#          Postal Code     Model Year  Electric Range      Base MSRP  \
# count  135030.000000  135038.000000   135037.000000  135037.000000
# mean    98171.001577    2019.662880       74.591964   81017.615211
# std      2450.367211       3.001676       98.744120   23727.350901
# min      1730.000000    1997.000000        0.000000   26455.735798
# 25%     98052.000000    2018.000000        0.000000   63713.207686
# 50%     98121.000000    2021.000000       21.000000   76983.777737
# 75%     98370.000000    2022.000000      150.000000  114632.706686
# max     99701.000000    2024.000000      337.000000  845000.000000
#
#        Legislative District    Vehicle ID  2020 Census Tract
# count         134726.000000  1.350380e+05       1.350300e+05
# mean              29.504379  2.063432e+08       5.297233e+10
# std               14.783780  8.582417e+07       1.635783e+09
# min                1.000000  4.385000e+03       1.081042e+09
# ...

# %%
data.tail()
# Out:
#         Identifier          City  Postal Code  Model Year        Make  \
# 135033  JTDKARFP0H  Port Angeles      98362.0        2017      TOYOTA
# 135034  5YJ3E1EB7L       Seattle      98134.0        2020       TESLA
# 135035  7FCTGAAL4N        Renton      98059.0        2022      RIVIAN
# 135036  WVGGNPE28N    Bellingham      98225.0        2022  VOLKSWAGEN
# 135037  2C4RC1N70L       Seattle      98126.0        2020    CHRYSLER
#
#               Model                   Electric Vehicle Type  \
# 135033  PRIUS PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
# 135034      MODEL 3          Battery Electric Vehicle (BEV)
# 135035          R1T          Battery Electric Vehicle (BEV)
# 135036         ID.4          Battery Electric Vehicle (BEV)
# 135037     PACIFICA  Plug-in Hybrid Electric Vehicle (PHEV)
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 135033              Not eligible due to low battery range            25.0
# ...

# %%
data.columns
# Out:
# Index(['Identifier', 'City', 'Postal Code', 'Model Year', 'Make', 'Model',
#        'Electric Vehicle Type',
#        'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Electric Range',
#        'Base MSRP', 'Legislative District', 'Vehicle ID', 'Vehicle Location',
#        'Electric Utility', '2020 Census Tract'],
#       dtype='object')

# %%
data.shape
# Out:
# (135038, 15)

# %%
data.nunique
# Out:
# <bound method DataFrame.nunique of         Identifier           City  Postal Code  Model Year        Make  \
# 0       KL8CL6S05E         Tacoma      98407.0        2014   CHEVROLET
# 1       JTDKARFP0H  Port Townsend      98368.0        2017      TOYOTA
# 2       JHMZC5F34J         Vashon      98070.0        2018       HONDA
# 3       KMHC65LD0K     Ridgefield      98642.0        2019     HYUNDAI
# 4       1N4AZ1CP6J      Bremerton      98337.0        2018      NISSAN
# ...            ...            ...          ...         ...         ...
# 135033  JTDKARFP0H   Port Angeles      98362.0        2017      TOYOTA
# 135034  5YJ3E1EB7L        Seattle      98134.0        2020       TESLA
# 135035  7FCTGAAL4N         Renton      98059.0        2022      RIVIAN
# 135036  WVGGNPE28N     Bellingham      98225.0        2022  VOLKSWAGEN
# 135037  2C4RC1N70L        Seattle      98126.0        2020    CHRYSLER
#
#               Model                   Electric Vehicle Type  \
# ...

# %%
data.isnull().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of         Identifier   City  Postal Code  Model Year   Make  Model  \
# 0            False  False        False       False  False  False
# 1            False  False        False       False  False  False
# 2            False  False        False       False  False  False
# 3            False  False        False       False  False  False
# 4            False  False        False       False  False  False
# ...            ...    ...          ...         ...    ...    ...
# 135033       False  False        False       False  False  False
# 135034       False  False        False       False  False  False
# 135035       False  False        False       False  False  False
# 135036       False  False        False       False  False  False
# 135037       False  False        False       False  False  False
#
#         Electric Vehicle Type  \
# 0                       False
# 1                       False
# ...

# %%
missing_values = data.isnull().sum()
print("Missing Values:\n", missing_values)
# Out:
# Missing Values:
#  Identifier                                             0
# City                                                   8
# Postal Code                                            8
# Model Year                                             0
# Make                                                   0
# Model                                                249
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                         1
# Base MSRP                                              1
# Legislative District                                 312
# Vehicle ID                                             0
# Vehicle Location                                      10
# Electric Utility                                       8
# 2020 Census Tract                                      8
# dtype: int64

# %%
duplicate_rows = data.duplicated().sum()
print("Duplicate Rows:", duplicate_rows)
# Out:
# Duplicate Rows: 0

# %%
summary_statistics = data.describe()
print("Summary Statistics:\n", summary_statistics)
# Out:
# Summary Statistics:
#           Postal Code     Model Year  Electric Range      Base MSRP  \
# count  135030.000000  135038.000000   135037.000000  135037.000000
# mean    98171.001577    2019.662880       74.591964   81017.615211
# std      2450.367211       3.001676       98.744120   23727.350901
# min      1730.000000    1997.000000        0.000000   26455.735798
# 25%     98052.000000    2018.000000        0.000000   63713.207686
# 50%     98121.000000    2021.000000       21.000000   76983.777737
# 75%     98370.000000    2022.000000      150.000000  114632.706686
# max     99701.000000    2024.000000      337.000000  845000.000000
#
#        Legislative District    Vehicle ID  2020 Census Tract
# count         134726.000000  1.350380e+05       1.350300e+05
# mean              29.504379  2.063432e+08       5.297233e+10
# std               14.783780  8.582417e+07       1.635783e+09
# min                1.000000  4.385000e+03       1.081042e+09
# ...

# %%
sns.pairplot(data) 
plt.show()

# %%
correlation_matrix = data.corr()
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='plasma')
plt.title('Correlation Matrix')
plt.show()
# Out:
# /tmp/ipykernel_174/2411693091.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = data.corr()

# %%
summary_stats = data.describe()
print(summary_stats)
# Out:
#          Postal Code     Model Year  Electric Range      Base MSRP  \
# count  135030.000000  135038.000000   135037.000000  135037.000000
# mean    98171.001577    2019.662880       74.591964   81017.615211
# std      2450.367211       3.001676       98.744120   23727.350901
# min      1730.000000    1997.000000        0.000000   26455.735798
# 25%     98052.000000    2018.000000        0.000000   63713.207686
# 50%     98121.000000    2021.000000       21.000000   76983.777737
# 75%     98370.000000    2022.000000      150.000000  114632.706686
# max     99701.000000    2024.000000      337.000000  845000.000000
#
#        Legislative District    Vehicle ID  2020 Census Tract
# count         134726.000000  1.350380e+05       1.350300e+05
# mean              29.504379  2.063432e+08       5.297233e+10
# std               14.783780  8.582417e+07       1.635783e+09
# min                1.000000  4.385000e+03       1.081042e+09
# ...

# %%
sns.pairplot(data)
plt.show()

# %%
correlation_matrix =data.corr()
# Out:
# /tmp/ipykernel_174/2653472692.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix =data.corr()

# %%
sns.distplot(data['Electric Vehicle Type'])
# Out:
# /tmp/ipykernel_174/577271904.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Electric Vehicle Type'])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_174/577271904.py in <cell line: 1>()
# ----> 1 sns.distplot(data['Electric Vehicle Type'])
#
# /usr/local/lib/python3.10/site-packages/seaborn/distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax, x)
#    2456
#    2457     # Make a a 1-d float array
# ...

# %%
sns.distplot(data['Electric Range'])
# Out:
# /tmp/ipykernel_174/3658146185.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Electric Range'])
# <AxesSubplot: xlabel='Electric Range', ylabel='Density'>

# %%
sns.distplot(data['Clean Alternative Fuel Vehicle (CAFV) Eligibility'])
# Out:
# /tmp/ipykernel_174/2845978164.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Clean Alternative Fuel Vehicle (CAFV) Eligibility'])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_174/2845978164.py in <cell line: 1>()
# ----> 1 sns.distplot(data['Clean Alternative Fuel Vehicle (CAFV) Eligibility'])
#
# ...

# %%
sns.distplot(data['City '])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'City '
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
sns.distplot(data['Model'])
# Out:
# /tmp/ipykernel_174/2954073812.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Model'])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_174/2954073812.py in <cell line: 1>()
# ----> 1 sns.distplot(data['Model'])
#
# /usr/local/lib/python3.10/site-packages/seaborn/distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax, x)
#    2456
#    2457     # Make a a 1-d float array
# ...

# %%
sns.distplot(data['Postal Code'])
# Out:
# /tmp/ipykernel_174/335839738.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Postal Code'])
# <AxesSubplot: xlabel='Postal Code', ylabel='Density'>

# %%
sns.distplot(data['Make'])
# Out:
# /tmp/ipykernel_174/939405310.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Make'])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_174/939405310.py in <cell line: 1>()
# ----> 1 sns.distplot(data['Make'])
#
# /usr/local/lib/python3.10/site-packages/seaborn/distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax, x)
#    2456
#    2457     # Make a a 1-d float array
# -> 2458     a = np.asarray(a, float)
# ...

# %%
for column in data.columns:
    plt.figure(figsize=(30, 30))
    sns.histplot(data[column], kde=True)
    plt.title('Histogram {data}')
    plt.xlabel('Make')
    plt.ylabel('city')
    plt.show()

# %%
for column in data.columns:
    plt.figure(figsize=(30, 30))
    sns.boxplot(x=data[column])
    plt.title( 'Relationshiop' {column}')
    plt.xlabel(count)
    plt.show()
# Out:
#   File "/tmp/ipykernel_174/857580264.py", line 4
#     plt.title( 'Relationshiop' {column}')
#                                        ^
# SyntaxError: unterminated string literal (detected at line 4)

# %%
    plt.figure(figsize=(30, 30))
    sns.histplot(data[column], kde=True)
    plt.title('Histogram {data}')
    plt.xlabel('Make')
    plt.ylabel('city')
    plt.show()

# %%
for column in data.columns:
    plt.figure(figsize=(8, 6))
    sns.histplot(data[column], kde=True)
    plt.title('Histogram {data}')
    plt.xlabel('Make')
    plt.ylabel('count')
    plt.show()

# %%
for column in data.columns:
    plt.figure(figsize=(8, 6))
    sns.histplot(data[column], kde=True)
    plt.title('Histogram {data}')
    plt.xlabel('count')
    plt.ylabel('city')
    plt.show()

# %%
outliers=[]
def detect_outliers(data)

threshold=}
mean=np.std(data)
std=np.std(data)

for i in data:
z_ score=(i-mean)/std
if np.abs(z_score) > threshold:
outliers.append(y)
return outliers

# %%
for column in data.columns:
    plt.figure(figsize=(8, 6))
    sns.boxplot(x=data[column])
    plt.title( 'Relationshiop' {column}')
    plt.xlabel(column)
    plt.show()

# %%
outliers=[]
def detect_outliers(data):

threshold=}
mean=np.std(data)
std=np.std(data)

for i in data:
z_ score=(i-mean)/std
if np.abs(z_score) > threshold:
outliers.append(i)
return outliers

# %%
outlier_pt=detect_outliers(data)

# %%
outlier_pt
